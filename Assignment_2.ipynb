# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
x = np.array([1,2,3,4,5,6])
y = np.power(x,3)

# %%
np.power(x,2)
# Out:
# array([ 1,  4,  9, 16, 25, 36])

# %%
plt.plot(x,y)

# %%
plt.style.use('seaborn-darkgrid')

# %%
plt.plot(x,y)

# %%
x = np.linspace(0,10,1000)
y = np.sin(x)

plt.plot(x,y)

# %%
plt.plot(x,y,'g',marker='o')

# %%
x = np.linspace(0,10,40)
y = np.sin(x)

plt.plot(x,y,'r',marker='o')

# %%
np.linspace(0,10,10)
# Out:
# array([ 0.        ,  1.11111111,  2.22222222,  3.33333333,  4.44444444,
#         5.55555556,  6.66666667,  7.77777778,  8.88888889, 10.        ])

# %%
plt.plot(x,y,'r',marker='o')
plt.xlabel('Actual Values')
plt.ylabel('Sin values')
# Out:
# Text(0, 0.5, 'Sin values')

# %%
x = np.array([1,2,3,4,5,6])
y1 = np.power(x,2)
y2 = np.power(x,3)

# %%
plt.plot(x,y1,'r',marker='o')
plt.plot(x,y2,'b',marker='o')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# Out:
# Text(0, 0.5, 'Y-Axis')

# %%
plt.plot(x,y1,'r',marker='o',label='Square')
plt.plot(x,y2,'b',marker='o',label='Cube')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend()

# %%
df
# Out:
#    Age  Salary Gender
# a   26   47000      M
# b   28   78000      M
# c   21   41000      M
# d   24   45212      M

# %%
df['Random']=np.random.rand(8)

# %%
df.loc['e']=[53,65481,'F']
df.loc['f']=[18,46052,'F']
df.loc['g']=[49,78254,'F']
df.loc['h']=[38,45698,'F']

# %%
df
# Out:
#    Age  Salary Gender    Random
# a   26   47000      M  0.119554
# b   28   78000      M  0.142244
# c   21   41000      M  0.425900
# d   24   45212      M  0.166857
# e   53   65481      F  0.553435
# f   18   46052      F  0.570539
# g   49   78254      F  0.707696
# h   38   45698      F  0.311980

# %%
plt.bar(df['Gender'],df['Age'])
# Out:
# <BarContainer object of 8 artists>

# %%
sns.countplot(df['Gender'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
dir(sns)
# Out:
# ['FacetGrid',
#  'JointGrid',
#  'PairGrid',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_core',
#  '_decorators',
#  '_docstrings',
#  '_orig_rc_params',
#  '_statistics',
#  'algorithms',
#  'axes_style',
#  'axisgrid',
#  'barplot',
#  'blend_palette',
#  'boxenplot',
#  'boxplot',
#  'categorical',
#  'catplot',
#  'choose_colorbrewer_palette',
#  'choose_cubehelix_palette',
#  'choose_dark_palette',
#  'choose_diverging_palette',
#  'choose_light_palette',
#  'clustermap',
#  'cm',
#  'color_palette',
#  'colors',
#  'countplot',
#  'crayon_palette',
#  'crayons',
#  'cubehelix_palette',
#  'dark_palette',
#  'desaturate',
#  'despine',
#  'displot',
#  'distplot',
#  'distributions',
#  'diverging_palette',
#  'dogplot',
#  'ecdfplot',
#  'external',
#  'factorplot',
#  'get_data_home',
#  'get_dataset_names',
#  'heatmap',
#  'histplot',
#  'hls_palette',
# ...

# %%
dir(plt)
# Out:
# ['Annotation',
#  'Arrow',
#  'Artist',
#  'AutoLocator',
#  'Axes',
#  'Button',
#  'Circle',
#  'Figure',
#  'FigureCanvasBase',
#  'FixedFormatter',
#  'FixedLocator',
#  'FormatStrFormatter',
#  'Formatter',
#  'FuncFormatter',
#  'GridSpec',
#  'IndexLocator',
#  'Line2D',
#  'LinearLocator',
#  'Locator',
#  'LogFormatter',
#  'LogFormatterExponent',
#  'LogFormatterMathtext',
#  'LogLocator',
#  'MaxNLocator',
#  'MultipleLocator',
#  'Normalize',
#  'NullFormatter',
#  'NullLocator',
#  'Number',
#  'PolarAxes',
#  'Polygon',
#  'Rectangle',
#  'ScalarFormatter',
#  'Slider',
#  'Subplot',
#  'SubplotTool',
#  'Text',
#  'TickHelper',
#  'Widget',
#  '_INSTALL_FIG_OBSERVER',
#  '_IP_REGISTERED',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_auto_draw_if_interactive',
#  '_backend_mod',
#  '_get_running_interactive_framework',
#  '_interactive_bk',
#  '_log',
#  '_pylab_helpers',
# ...

# %%
sns.boxplot(df['Random'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df['Age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Data Wrangling & Data Pre-Processing

# %%
df = pd.read_csv('/content/Data1.csv')

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df.head()
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes

# %%
df.tail(2)
# Out:
#    Country   Age   Salary Purchased
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df.shape
# Out:
# (10, 4)

# %%
df.describe()
# Out:
#              Age        Salary
# count   9.000000      9.000000
# mean   38.777778  63777.777778
# std     7.693793  12265.579662
# min    27.000000  48000.000000
# 25%    35.000000  54000.000000
# 50%    38.000000  61000.000000
# 75%    44.000000  72000.000000
# max    50.000000  83000.000000

# %%
df.describe(include='all')
# Out:
#        Country        Age        Salary Purchased
# count       10   9.000000      9.000000        10
# unique       3        NaN           NaN         2
# top     France        NaN           NaN        No
# freq         4        NaN           NaN         5
# mean       NaN  38.777778  63777.777778       NaN
# std        NaN   7.693793  12265.579662       NaN
# min        NaN  27.000000  48000.000000       NaN
# 25%        NaN  35.000000  54000.000000       NaN
# 50%        NaN  38.000000  61000.000000       NaN
# 75%        NaN  44.000000  72000.000000       NaN
# max        NaN  50.000000  83000.000000       NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    10 non-null     object
#  1   Age        9 non-null      float64
#  2   Salary     9 non-null      float64
#  3   Purchased  10 non-null     object
# dtypes: float64(2), object(2)
# memory usage: 448.0+ bytes

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df.isnull().sum()
# Out:
# Country      0
# Age          1
# Salary       1
# Purchased    0
# dtype: int64

# %%
df['Age'].median(), df['Salary'].mean()
# Out:
# (38.0, 63777.77777777778)

# %%
df['Age']=df['Age'].fillna(df['Age'].median())

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  38.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df['Salary']=df['Salary'].fillna(df['Salary'].mean())
df
# Out:
#    Country   Age        Salary Purchased
# 0   France  44.0  72000.000000        No
# 1    Spain  27.0  48000.000000       Yes
# 2  Germany  30.0  54000.000000        No
# 3    Spain  38.0  61000.000000        No
# 4  Germany  40.0  63777.777778       Yes
# 5   France  35.0  58000.000000       Yes
# 6    Spain  38.0  52000.000000        No
# 7   France  48.0  79000.000000       Yes
# 8  Germany  50.0  83000.000000        No
# 9   France  37.0  67000.000000       Yes

# %%
df[df['Age']>40]
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No

# %%
df[df['Salary']>80000]
# Out:
#    Country   Age   Salary Purchased
# 8  Germany  50.0  83000.0        No

# %%
# Encoding

# %%
# Method 1 (Label Encoding)

# %%
from sklearn.preprocessing import LabelEncoder
from collections import Counter as count

# %%
le = LabelEncoder()

# %%
df['Country'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
count(df['Country'])
# Out:
# Counter({'France': 4, 'Spain': 3, 'Germany': 3})

# %%
df['Country']=le.fit_transform(df['Country'])

# %%
count(df['Country'])
# Out:
# Counter({0: 4, 2: 3, 1: 3})

# %%
df
# Out:
#    Country   Age        Salary Purchased
# 0        0  44.0  72000.000000        No
# 1        2  27.0  48000.000000       Yes
# 2        1  30.0  54000.000000        No
# 3        2  38.0  61000.000000        No
# 4        1  40.0  63777.777778       Yes
# 5        0  35.0  58000.000000       Yes
# 6        2  38.0  52000.000000        No
# 7        0  48.0  79000.000000       Yes
# 8        1  50.0  83000.000000        No
# 9        0  37.0  67000.000000       Yes

# %%
# Method 2 (Feature map)

# %%
count(df['Purchased'])
# Out:
# Counter({'No': 5, 'Yes': 5})

# %%
df['Purchased']=df['Purchased'].replace(['No','Yes'],[0,1])

# %%
count(df['Purchased'])
# Out:
# Counter({0: 5, 1: 5})

# %%
# Method 3 (One hot encoding)

# %%
df1 = pd.read_csv('/content/Data1.csv')

# %%
df1['Country']
# Out:
# 0     France
# 1      Spain
# 2    Germany
# 3      Spain
# 4    Germany
# 5     France
# 6      Spain
# 7     France
# 8    Germany
# 9     France
# Name: Country, dtype: object

# %%
country = pd.get_dummies(df1['Country'],prefix='Country_')

# %%
country
# Out:
#    Country__France  Country__Germany  Country__Spain
# 0                1                 0               0
# 1                0                 0               1
# 2                0                 1               0
# 3                0                 0               1
# 4                0                 1               0
# 5                1                 0               0
# 6                0                 0               1
# 7                1                 0               0
# 8                0                 1               0
# 9                1                 0               0

# %%
# Spliting the data (train and test split)

# %%
df
# Out:
#    Country   Age        Salary  Purchased
# 0        0  44.0  72000.000000          0
# 1        2  27.0  48000.000000          1
# 2        1  30.0  54000.000000          0
# 3        2  38.0  61000.000000          0
# 4        1  40.0  63777.777778          1
# 5        0  35.0  58000.000000          1
# 6        2  38.0  52000.000000          0
# 7        0  48.0  79000.000000          1
# 8        1  50.0  83000.000000          0
# 9        0  37.0  67000.000000          1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    10 non-null     int64
#  1   Age        10 non-null     float64
#  2   Salary     10 non-null     float64
#  3   Purchased  10 non-null     int64
# dtypes: float64(2), int64(2)
# memory usage: 448.0 bytes

# %%
x=df.iloc[:,0:3]
y=df['Purchased']

# %%
x
# Out:
#    Country   Age        Salary
# 0        0  44.0  72000.000000
# 1        2  27.0  48000.000000
# 2        1  30.0  54000.000000
# 3        2  38.0  61000.000000
# 4        1  40.0  63777.777778
# 5        0  35.0  58000.000000
# 6        2  38.0  52000.000000
# 7        0  48.0  79000.000000
# 8        1  50.0  83000.000000
# 9        0  37.0  67000.000000

# %%
y
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    1
# 5    1
# 6    0
# 7    1
# 8    0
# 9    1
# Name: Purchased, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=11)

# %%
xtrain
# Out:
#    Country   Age        Salary
# 6        2  38.0  52000.000000
# 4        1  40.0  63777.777778
# 5        0  35.0  58000.000000
# 1        2  27.0  48000.000000
# 3        2  38.0  61000.000000
# 0        0  44.0  72000.000000
# 9        0  37.0  67000.000000

# %%
xtest
# Out:
#    Country   Age   Salary
# 7        0  48.0  79000.0
# 8        1  50.0  83000.0
# 2        1  30.0  54000.0

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
st = StandardScaler()
nm = MinMaxScaler()

# %%
s_xtrain = st.fit_transform(xtrain)
s_xtrain
# Out:
# array([[ 1.08012345,  0.20659847, -1.065811  ],
#        [ 0.        ,  0.6197954 ,  0.45501931],
#        [-1.08012345, -0.41319694, -0.29104839],
#        [ 1.08012345, -2.06598468, -1.5823194 ],
#        [ 1.08012345,  0.20659847,  0.09633292],
#        [-1.08012345,  1.44618927,  1.51673104],
#        [-1.08012345,  0.        ,  0.87109553]])

# %%
s_xtest = st.transform(xtest)

# %%
s_xtest
# Out:
# array([[-1.08012345,  2.27258314,  2.42062075],
#        [ 0.        ,  2.68578008,  2.93712915],
#        [ 0.        , -1.44618927, -0.80755679]])

# %%
n_xtrain = nm.fit_transform(xtrain)
n_xtrain
# Out:
# array([[1.        , 0.64705882, 0.16666667],
#        [0.5       , 0.76470588, 0.65740741],
#        [0.        , 0.47058824, 0.41666667],
#        [1.        , 0.        , 0.        ],
#        [1.        , 0.64705882, 0.54166667],
#        [0.        , 1.        , 1.        ],
#        [0.        , 0.58823529, 0.79166667]])

# %%
n_xtest = nm.transform(xtest)
n_xtest
# Out:
# array([[0.        , 1.23529412, 1.29166667],
#        [0.5       , 1.35294118, 1.45833333],
#        [0.5       , 0.17647059, 0.25      ]])
